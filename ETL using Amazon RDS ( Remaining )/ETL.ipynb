# %% [markdown]
# # Extract Load  Transform Pipeline
# ### ETL Pipeline

# %% [markdown]
# Database se data layenge
# Then usme 1 Transformation hoga then usko uthake hum Dusre Database mai store karenge.

# %% [markdown]
# ![image.png](attachment:image.png)
