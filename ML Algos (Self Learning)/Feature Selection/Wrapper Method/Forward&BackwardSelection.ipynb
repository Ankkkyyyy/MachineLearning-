# %%
import pandas as pd 
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.model_selection import cross_val_predict
import pandas as pd 
from sklearn.model_selection import cross_val_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install --upgrade scikit-learn mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df =pd.read_csv("HousingData.csv")

# %%
df.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(df.iloc[:,:-1],df['MEDV'],test_size=0.2,random_state=20)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (315, 13)
# (79, 13)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# If Forward Selection krna hoo tou
# forward ko True krdo bss
# SFS = SFS(model,k_features='best',forward=True,floating=False,scoring='r2',cv=5)

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
model = LinearRegression()


SFS = SFS(model,k_features='best',forward=False,floating=False,scoring='r2',cv=5)

SFS.fit(x_train,y_train)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), forward=False,
#                           k_features=(1, 13), scoring='r2')

# %%
SFS.k_feature_idx_
# Out:
# (0, 1, 4, 5, 7, 8, 9, 10, 11, 12)

# %%
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs

# %%
plot_sfs(SFS.get_metric_dict(), kind='std_err')

plt.title("Sequential Backward Elimination ")
plt.grid()
