# %%
import pandas as pd

# %%
df = pd.read_csv("breast-cancer.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop(columns=['id'],inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
df.iloc[:,1:]
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
# df.iloc[:,0]
df['diagnosis']
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
x_train,x_test,y_train,y_test = train_test_split(df.iloc[:,1:],df['diagnosis'],test_size=0.2,random_state=2)

# %%
# x_train
# y_train

# %%
x_train.shape
# Out:
# (455, 30)

# %%
x_train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 560        14.05         27.15           91.38      600.4          0.09929
# 428        11.13         16.62           70.47      381.1          0.08151
# 198        19.18         22.49          127.50     1148.0          0.08523
# 203        13.81         23.75           91.56      597.8          0.13230
# 41         10.95         21.35           71.90      371.1          0.12270
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 560           0.11260         0.04462              0.04304         0.1537
# 428           0.03834         0.01369              0.01370         0.1511
# 198           0.14280         0.11140              0.06772         0.1767
# 203           0.17680         0.15580              0.09176         0.2251
# 41            0.12180         0.10440              0.05669         0.1895
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# ...

# %%
y_train.shape
# Out:
# (455,)

# %% [markdown]
# Jbh bhi KNN use karo tou yaadse
# Scale pe laao sbh Data ko coz, KNN pura reliye krta hai Distance pe so its
# important ki sbh datapoint scale pr hoo

# %%
from sklearn.preprocessing import StandardScaler  

scalar = StandardScaler() 

x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

# %%
x_train.shape
# Out:
# (455, 30)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.predict(x_test)
# Out:
# array(['B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M',
#        'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M'], dtype=object)

# %%
y_pred = knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9736842105263158

# %% [markdown]
# Better is to Find it through Experimentation
# Lyk through Cross Validation

# %%
scores = []


for i in range(1,16):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    y_pred = knn.predict(x_test)
    scores.append(accuracy_score(y_test,y_pred))

# %%
scores
# Out:
# [0.956140350877193,
#  0.9736842105263158,
#  0.9912280701754386,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9649122807017544,
#  0.9649122807017544]

# %% [markdown]
# When k is 3 at that time we getting Highest accuracy as 99

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn.predict(x_test)
y_pred =knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9912280701754386

# %% [markdown]
# ## Decision Surface or Decision Boundary
