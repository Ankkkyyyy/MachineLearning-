# %% [markdown]
# # Data Gathering
#
# 1.) data import (csv,excel, text,json, database)
# 2.) data export (csv,excel, text,json, database,HTML)
# 3.) Data from API
# 4.) Data From Web Scrapping

# %% [markdown]
# # Data Imports From CSV File

# %% [markdown]
# ###  Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Opening a local csv file

# %%
df=pd.read_csv("../Datasets/aug_train.csv")
# df.head(2)
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# ### Opening a CSV file from an URL

# %%
import requests 
from io import StringIO

url = ""
url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url,headers=headers)
data = StringIO(req.text)
pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ### Sep Paramter
#
# e.g in tsv files tab separated values - comma se nahi tab se seperate hote hai yeah

# %%
# tsv = tab separated value 
# pd.read_csv('Datasets/movie_titles_metadata.tsv')
pd.read_csv('Datasets/movie_titles_metadata.tsv',sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18916\489121084.py in <module>
#       1 # tsv = tab separated value
#       2 # pd.read_csv('Datasets/movie_titles_metadata.tsv')
# ----> 3 pd.read_csv('Datasets/movie_titles_metadata.tsv',sep='\t')
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# Above you can see that column ka naam nahi hai so in that case what we can do is
# pass the Names parameter

# %%
pd.read_csv('Datasets/movie_titles_metadata.tsv',sep='\t',names=['srno','movie name','release under year','ratings','No of Votes','Genre'])
# Out:
#      srno                  movie name release under year  ratings  \
# 0      m0  10 things i hate about you               1999      6.9
# 1      m1  1492: conquest of paradise               1992      6.2
# 2      m2                  15 minutes               2001      6.1
# 3      m3       2001: a space odyssey               1968      8.4
# 4      m4                     48 hrs.               1982      6.9
# ..    ...                         ...                ...      ...
# 612  m612                    watchmen               2009      7.8
# 613  m613                         xxx               2002      5.6
# 614  m614                       x-men               2000      7.4
# 615  m615          young frankenstein               1974      8.0
# 616  m616                   zulu dawn               1979      6.4
#
#      No of Votes                                              Genre
# 0        62847.0                               ['comedy' 'romance']
# ...

# %% [markdown]
# ### Index Col Parameter

# %%
pd.read_csv('Datasets/aug_train.csv',index_col='enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %% [markdown]
# ### Header Parameter

# %%
pd.read_csv('Datasets/test.csv')
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
# 2           2        11561    city_21                   0.624        NaN
# 3           3        33241   city_115                   0.789        NaN
# 4           4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# ...

# %%
pd.read_csv('Datasets/test.csv',header=1)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %% [markdown]
# ### use_cols parameter
#
# suppose mujhe dataset se bss 2-3 columns chaye bss so hum yeah parameter mai vo column pass krke apna kaam karskte hai

# %%
pd.read_csv("Datasets/aug_train.csv",usecols=['enrollee_id','city','gender','relevent_experience','experience'])
# Out:
#        enrollee_id      city gender      relevent_experience experience
# 0             8949  city_103   Male  Has relevent experience        >20
# 1            29725   city_40   Male   No relevent experience         15
# 2            11561   city_21    NaN   No relevent experience          5
# 3            33241  city_115    NaN   No relevent experience         <1
# 4              666  city_162   Male  Has relevent experience        >20
# ...            ...       ...    ...                      ...        ...
# 19153         7386  city_173   Male   No relevent experience         14
# 19154        31398  city_103   Male  Has relevent experience         14
# 19155        24576  city_103   Male  Has relevent experience        >20
# 19156         5756   city_65   Male  Has relevent experience         <1
# 19157        23834   city_67    NaN   No relevent experience          2
#
# [19158 rows x 5 columns]

# %% [markdown]
# ### Squeeze parameters
#
# jbh bss 1 hie column chaye hota hai so use squeeze ishse series miljayega vo 1 specified vala
#
# Itna kaam nahi aata hai generally

# %%
pd.read_csv('Datasets/aug_train.csv',usecols=['gender'],squeeze=True)
# Out:
# 0        Male
# 1        Male
# 2         NaN
# 3         NaN
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157     NaN
# Name: gender, Length: 19158, dtype: object

# %% [markdown]
# ### Skiprows/nrows Parameter

# %%
# skiprows
pd.read_csv('Datasets/aug_train.csv')
pd.read_csv('Datasets/aug_train.csv',skiprows=[0,1])
# Out:
#        29725   city_40  0.7759999999999999  Male   No relevent experience  \
# 0      11561   city_21               0.624   NaN   No relevent experience
# 1      33241  city_115               0.789   NaN   No relevent experience
# 2        666  city_162               0.767  Male  Has relevent experience
# 3      21651  city_176               0.764   NaN  Has relevent experience
# 4      28806  city_160               0.920  Male  Has relevent experience
# ...      ...       ...                 ...   ...                      ...
# 19151   7386  city_173               0.878  Male   No relevent experience
# 19152  31398  city_103               0.920  Male  Has relevent experience
# 19153  24576  city_103               0.920  Male  Has relevent experience
# 19154   5756   city_65               0.802  Male  Has relevent experience
# 19155  23834   city_67               0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate             STEM   15    50-99  \
# ...

# %%
# nrows -- restriction daaldeta hai number of rows pe eg above dekhskte hai ki 19156 rows hai let's restrict it to 100 
pd.read_csv('Datasets/aug_train.csv',skiprows=[0,1],nrows=100)
# Out:
#     29725   city_40  0.7759999999999999  Male   No relevent experience  \
# 0   11561   city_21               0.624   NaN   No relevent experience
# 1   33241  city_115               0.789   NaN   No relevent experience
# 2     666  city_162               0.767  Male  Has relevent experience
# 3   21651  city_176               0.764   NaN  Has relevent experience
# 4   28806  city_160               0.920  Male  Has relevent experience
# ..    ...       ...                 ...   ...                      ...
# 95  11184   city_74               0.579   NaN   No relevent experience
# 96   7016   city_65               0.802  Male  Has relevent experience
# 97   8695   city_11               0.550  Male  Has relevent experience
# 98   6172   city_11               0.550  Male  Has relevent experience
# 99  14672  city_173               0.878   NaN   No relevent experience
#
#        no_enrollment     Graduate             STEM   15    50-99  \
# ...

# %% [markdown]
# ### Encoding Parameter
#
# yeah usefull hai for encoding

# %%
pd.read_csv('Datasets/zomato.csv',encoding="latin-1")
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# ### Skip Bad Lines

# %%
# pd.read_csv('Datasets/BX-Books.csv',sep=';',encoding='latin-1')
# parser Error - row 6452 mai 8 field mai 9 columns hai 
# so in this case pass parameter error_bad_lines=False
pd.read_csv('Datasets/BX-Books.csv',sep=';',encoding='latin-1',error_bad_lines=False)
# Out:
# C:\Users\hp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# ...

# %% [markdown]
# ### dtypes parameter

# %%
pd.read_csv("Datasets/aug_train.csv")
# Target mai bss 1.0 hai & 0 hai 
pd.read_csv("Datasets/aug_train.csv",dtype={'target':'int'})
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# ### Handling Dates

# %%
pd.read_csv('Datasets/IPL Matches 2008-2020.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
# dates object aarha so as we know pandas mai object mtlb string 
pd.read_csv('Datasets/IPL Matches 2008-2020.csv',parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# ### Convertors
#
# It is helpfull whenever we have to apply conversion

# %%
def rename (name):
    if name=='Royal Challengers Bangalore':
        return "RCB"
    else:
        return name 

pd.read_csv("Datasets/IPL Matches 2008-2020.csv",converters={ 'team1':rename})
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# ### na_values parameter
#
# yeah empty value banadega mostly placeholder mai use karenge hum ishe

# %%
pd.read_csv('Datasets/aug_train.csv',na_values=['Male'])
# yeah empty value banadega mostly placeholder mai use karenge hum ishe
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# ### Loading a huge dataset in  chunks
# Bade dataset load krte time yeah kaam aata hai

# %%
dfs=pd.read_csv('Datasets/aug_train.csv',chunksize=5000)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)

# %% [markdown]
# # Data Imports From Excel File

# %%
pd.read_excel('Datasets/Book3.xlsx',index_col='Item Code')
# Out:
#                       Item Code Comman                  Description  \
# Item Code
# FCF707020890  21000207 L6 FCF707020890        BLIND FLANGE 32 A 300
# FCHC01040890  21000207 L6 FCHC01040890  HALF COUPLING-1/2" SW-#3000
# FCHC03040890  21000207 L6 FCHC03040890   HALF COUPLING-3/4"SW-#3000
# FCCH01070890  21000211 L6 FCCH01070890  CAP 1/2" # 3000 NPT SCREWED
# FCF3Q3010890  21000211 L6 FCF3Q3010890         WNRF FLANGE 20 A 150
# FCF3Q3261190  21000210 L6 FCF3Q3261190         WNRF FLANGE 20 A 600
# NaN                                NaN                          NaN
# NaN                                NaN                          NaN
# NaN                                NaN                          NaN
# NaN                                NaN                          NaN
# NaN                                NaN                          NaN
# FCF3Q5261190  21000212 L6 FCF3Q5261190         WNRF FLANGE 25 A 600
# NaN                                NaN                          NaN
# ...

# %%
pd.read_excel('Datasets/RajeevGandhiclg.xlsx')
# Out:
# Students list
#                                            Unnamed: 0          Unnamed: 1  \
# 0   JUHU -VERSOVA LINK ROAD, ANDHERI (W.), MUMBAI ...                 NaN
# 1                                       Annexture-1 A                 NaN
# 2                                                 ...                 NaN
# 3                                            Sr. No.   Date of Interviews
# 4                                                   1                 NaN
# ..                                                ...                 ...
# 79                                                 76                 NaN
# 80                                                 77                 NaN
# 81                                                 78                 NaN
# 82                                                NaN               TOTAL
# 83                                                NaN         GRAND TOTAL
#
# ...

# %% [markdown]
# if different sheets hai so if u wnna access that
# use sheet_name

# %% [markdown]
# # Reading text files

# %%
# use yeahi hoga but thoda changes krenge hum isme 
import pandas as pd
pd.read_csv("../Datasets/DSEcollegelist_unsorted.txt",sep='\t')
# Out:
#    ---------------------------------------------Mumbai ------------------------------------------
# 0   pillai - (Un-Aided - Autonomous- minority- mal...
# 1   Datta meghe (AI,DS,CO,IT)---------------------...
# 2   Lokmanya tilak - (CO,AI,ML,CBS-iot blockchain)...
# 3   Fr.c Rodrigues- Vashi navi mumbai (CO,IT)-----...
# 4                   A.P .Shah  - Thane (CO,AI,DS ,It)
# 5   Vidyalankar ,Wadala- (CO,IT)------------------...
# 6   Xavier-mahim  (CO,IT)-------------------------...
# 7       Manjara , Rajiv gandhi, Mumbai -(AI,CD,CO,IT)
# 8   Shah & Anchor, (CO,CS,AI,DS,IT)---------------...
# 9   Thakur,(CS,CO,AI,DS,IT)-----------------------...
# 10  Fr.C Rodriges,Bandra (CO,AI-DS)---------------...
# 11  Vivekanand chembur(AI,DC,CO,IT)---------------...
# 12             DJ Sangvi (CO,IT, AI_DS,CSE_ DS,AI-ML)
# 13  ST,Francis Borivli (CO,IT)--------------------...
# 14  Don Bosco (CO,IT)-----------------------------...
# 15                           K J Somaiya Sion (CO,IT)
# ...

# %% [markdown]
# # Data Import from JSON file
# Javascript object Notation
# JSON ka zyaada use API use karte time hota hai  jbh API pe hit krte hai tbh return mai vo JSON deta hai
