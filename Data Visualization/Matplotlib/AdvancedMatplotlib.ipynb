# %% [markdown]
# # Advanced Matplotlib

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Colored ScatterPlot

# %%
iris = pd.read_csv('Dataset2/iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
# Out:
# Text(0, 0.5, 'Petal Length')

# %% [markdown]
# ### Color Encode on different categories

# %% [markdown]
# c=iris['Species'],cmap='jet'
#
# plt.colorbar() # ishse dekhke data kebaremeah labelling dekhskte hum
#
# ### graph size
#
# plt.figure(figsize(width,height))

# %%
plt.figure(figsize=(10,7))
iris['Species'] =iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
# iris.sample(5)
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar() # ishse dekhke data kebaremeah labelling dekhskte hum

# %% [markdown]
# ### Annotations
# Yeah use karke hum apne graph pe ek text ko place karsakte hai

# %%
batters = pd.read_csv('Dataset2/batter.csv')
batters.head(3)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577

# %%
# top 100 nikallenge & unsmese random 25 log ko select karenge  
top100batsman = batters.head(100).sample(25,random_state=5)
top100batsman
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.figure(figsize=(15,10))
plt.scatter(top100batsman['avg'],top100batsman['strike_rate'],s=top100batsman['runs'])

for i in range(top100batsman.shape[0]):
    plt.text(top100batsman['avg'].values[i],top100batsman['strike_rate'].values[i],top100batsman['batter'].values[i])

# %% [markdown]
# ### Horizontal & Vertical Lines for Graph
# plt.axhline(130,color='red')

# %% [markdown]
# #### Qs. i am the owner of my IPL team i only wnna bif for the batsman whose strike rate is greater than 130

# %%
# i am the owner of my IPL team i only wnna bif for the batsman whose strike rate is greater than 130 
plt.figure(figsize=(15,10))
plt.scatter(top100batsman['avg'],top100batsman['strike_rate'],s=top100batsman['runs'])

plt.axhline(130,color='red')

for i in range(top100batsman.shape[0]):
    plt.text(top100batsman['avg'].values[i],top100batsman['strike_rate'].values[i],top100batsman['batter'].values[i])

# %% [markdown]
# #### Qs. Findout the batsman whose strike rate is greater than 130 & average is also more than 30

# %%
plt.figure(figsize=(15,10))
plt.scatter(top100batsman['avg'],top100batsman['strike_rate'],s=top100batsman['runs'])

plt.axhline(130,color='red')
plt.axhline(140,color='green')
plt.axvline(30,color='red')

for i in range(top100batsman.shape[0]):
    plt.text(top100batsman['avg'].values[i],top100batsman['strike_rate'].values[i],top100batsman['batter'].values[i],fontdict={'size':12})

# %% [markdown]
# ## Subplots
#
# Whenever we are dealing with multiple columns tbhi at that time Subplots use karskte hai

# %% [markdown]
# ## Alternate way of Plotting Matplotlib Graph
#
# Yeah alternative way isliye helpful hai ki side by side hum multiple graph plot karsakte hai

# %%
# Alternate way of Plotting Matplotlib Graph 

fig, ax  = plt.subplots(figsize=(10,6)) # size bhi yeahi deskte yeah alternative way mai 
ax.scatter(batters['avg'],batters['strike_rate'])
ax.set_title('yo')
ax.set_xlabel('avg')
ax.set_ylabel('strike rate')

# plt.show() ke jageh fig.show()
# Out:
# Text(0, 0.5, 'strike rate')

# %%
fig ,ax  = plt.subplots(nrows=2,ncols=1)

# %%
fig ,ax  = plt.subplots(nrows=2,ncols=1,sharex=True,figsize=(10,6))
ax[0].scatter(batters['avg'],batters['strike_rate'],color='red')
ax[1].scatter(batters['avg'],batters['runs'])


ax[0].set_title('Avg Vs Strike Rate')
# ax[0].set_xlabel('Average')
ax[0].set_ylabel('Strike Rate')

ax[1].set_title('Avg Vs runs')
ax[1].set_xlabel('Average')
ax[1].set_ylabel('Runs')
# Out:
# Text(0, 0.5, 'Runs')

# %%
fig ,ax  = plt.subplots(nrows=2,ncols=2,figsize=(10,10))

ax[0,0].scatter(batters['avg'],batters['strike_rate'],color='red')
ax[0,1].scatter(batters['avg'],batters['runs'])
ax[1,0].hist(batters['avg'])
ax[1,1].hist(batters['runs'])

# ax[0,0].set_title('Avg Vs Strike Rate')
# ax[0].set_xlabel('Average')
# ax[0,1].set_ylabel('Strike Rate')

# ax[1].set_title('Avg Vs runs')
# ax[1].set_xlabel('Average')
# ax[1].set_ylabel('Runs')
# Out:
# (array([499.,  40.,  19.,  19.,   9.,   6.,   4.,   4.,   3.,   2.]),
#  array([   0. ,  663.4, 1326.8, 1990.2, 2653.6, 3317. , 3980.4, 4643.8,
#         5307.2, 5970.6, 6634. ]),
#  <BarContainer object of 10 artists>)

# %%
# 3rd Way 


fig =plt.figure()

ax1 = fig.add_subplot(2,2,1)
ax1.scatter(batters['avg'],batters['strike_rate'],color='red')

ax2 = fig.add_subplot(2,2,2)
ax2.hist(batters['avg'])

ax3 = fig.add_subplot(2,2,3)
ax3.hist(batters['runs'])
# Out:
# (array([499.,  40.,  19.,  19.,   9.,   6.,   4.,   4.,   3.,   2.]),
#  array([   0. ,  663.4, 1326.8, 1990.2, 2653.6, 3317. , 3980.4, 4643.8,
#         5307.2, 5970.6, 6634. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 3-D Plots

# %% [markdown]
# ## 3D Scatter Plots

# %%
batters.head(2)
# Out:
#      batter  runs        avg  strike_rate
# 0   V Kohli  6634  36.251366   125.977972
# 1  S Dhawan  6244  34.882682   122.840842

# %%
fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter(batters['runs'],batters['avg'],batters['strike_rate'],marker='+')

ax.set_title('IPL Batsman Insights')

ax.set_xlabel('Runs')
ax.set_ylabel('Average')
ax.set_zlabel('Strike Rate')
# Out:
# Text(0.5, 0, 'Strike Rate')

# %% [markdown]
# ## 3D Line Plots

# %%
x = [0,1,5,25]
y = [0,10,13,0]
z = [0,13,20,9]

fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter(x,y,z,marker='+',s=[100,100,100,100])

ax.plot3D(x,y,z,color='red')

# %% [markdown]
# ## Surface Plot
# Yeahi most probably zyaada use hoga at time of Loss Function,
# Loss Function humme yeah batata hai ki , ek Machine Learning Algorithm ka result kitna sahi ya kitna galat hai
#
# ### At ML tbhi yeah use hoga Loss Function ko Plot karte time

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy  =np.meshgrid(x,y)

# %%
z = xx**2+yy**2
z.shape
# Out:
# (100, 100)

# %%
fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')
p=ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
# Random stuff
z =np.sin(xx) + np.cos(yy)
fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')
p=ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# ## Contour Plot
#
# 3d graph  ko 2d graph krna hoo tbh

# %%
fig = plt.figure(figsize=(12,8))

ax = plt.subplot()
p=ax.contour(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
fig = plt.figure(figsize=(12,8))

ax = plt.subplot()
p= ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# ## HeatMap

# %%
# x - balls , y - balls
delivery = pd.read_csv('dataset2/IPL_Ball_by_Ball_2008_2022.csv')
delivery.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
plt.figure(figsize=(20,10))
temp_df= delivery[delivery['ballnumber'].isin([1,2,3,4,5,6]) & (delivery['batsman_run']==6)]
grid = temp_df.pivot_table(index='overs',columns='ballnumber',values='batsman_run',aggfunc='count')

plt.imshow(grid)
plt.colorbar()

# %% [markdown]
# ## Pandas Plot()
#
# Plot is a function present in pandas using which we can plot matplotlib graphs inside pandas
#
# Series & Dataframe dono pe kaam krta hai yeah

# %%
s = pd.Series([1,2,3,4,5,6,7,8,9])
s.plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='None'>

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# Scatter plot 

tips.plot(kind='scatter',x='total_bill',y='tip',title='Cost Analysis',c='sex',cmap='viridis'  ,marker='+',figsize=(6,2),s='size')#color='red'
# Out:
# <AxesSubplot: title={'center': 'Cost Analysis'}, xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Bar Chart

# %%
# Bar Chart 
tempdf = pd.read_csv('Dataset2/batsman_season_record.csv')
tempdf

tempdf.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
tempdf['2015'].plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
tempdf.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot: >

# %%
tips.groupby('sex')['total_bill'].mean().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='sex'>

# %% [markdown]
#  Histogram
#
#  Pie

# %%
# Pie  Single & Multiple 

df = pd.DataFrame(
    {
        'batsman':['Dhawan','Rohit','Kohli','SKY','Pandya','Pant'],
        'match1':[120,20,190,10,100,100],
        'match2':[20,120,19,5,10,3],
        'match3':[12,2,9,30,1,10],


})

df['match1'].plot(kind='pie',labels=df['batsman'].values)
# Out:
# <AxesSubplot: ylabel='match1'>

# %%
# Multiple Pie charts
df[['match1','match2','match3']].plot(kind='pie',subplots=True,figsize=(15,9))
# Out:
# array([<AxesSubplot: ylabel='match1'>, <AxesSubplot: ylabel='match2'>,
#        <AxesSubplot: ylabel='match3'>], dtype=object)

# %%
tips.head(2)
tips.pivot_table(index='day',columns='sex',values='total_bill',aggfunc='mean').plot(kind='line')
# Out:
# <AxesSubplot: xlabel='day'>

# %%
tips.pivot_table(index=['day','time'],columns=['sex','smoker'],values='total_bill',aggfunc='mean').plot(kind='line',figsize=(12,8))
# Out:
# <AxesSubplot: xlabel='day,time'>
